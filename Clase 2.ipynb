# %%
from pylab import *
# %matplotlib inline

# %%
def func(x):
    # tabs son importantes!
    y = x**2
    return y

# %%
x = linspace(0,2)
plot(x,func(x))

# %%
#plot necesita que las dos variables tengan la misma dimensión

# %%
def func2(x):
    # tabs son importantes!
    y = x**3
    return y

# %%
a = "hola mundo"
def hola():
    a = "hola de nuevo"
    print a
print a 
hola ()
# Out:
# hola mundo
# hola de nuevo

# %%
plot(x,func(x),x,func2(x))
xlim(0,1)
ylim(0,1)
# Out:
# (0, 1)

# %%
def func3(a):
    # tabs son importantes!
    x = linspace (0,a) 
    y = x**3
    plot (x,y,'red')

# %%
func3(1)

# %%
x= linspace(0,6)
puntosy = [1,3,2,5,0.2]
puntosx = [0,1,2,3,4]
plot (puntosx, puntosy,'o')
show()
plot (x,func(x))

# %%
#'o' deja solo puntos

# %%
def func4(x,exponente):
    return x**exponente

# %%
for i in range(8):
    y=func4(x,i)
    plot(x,y)

# %%
range(3)
# Out:
# [0, 1, 2]

# %%
arange(0,2,0.5)
# Out:
# array([ 0. ,  0.5,  1. ,  1.5])

# %%
platillos = [100,130,30]
len(platillos)
# Out:
# 3

# %%
def cuenta(platillos,propina):
    total = 0
    for i in range(len(platillos)):
        total += platillos[i]
        
    total=total+total*propina
    print total

# %%
platillos = [50,23,40,121,154]
propina = 0.10
cuenta(platillos,0.03)
# Out:
# 399.64

# %%
#def siempre termina con : igual que for, if
